# %%
import pymc3 as pm
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import theano
import sympy
from pymc3.distributions import Continuous
from pymc3.distributions import distribution
# %matplotlib inline

# %% [markdown]
# ## This notebook will test the probablilistic programming modeule PyMC

# %% [markdown]
# ### Below we we will attempt to recover the true parameter of our normally distributed data , we do this by defining our likelihood function as | inj - inf | and say that on average this gives 0 from our observations. the inf_param is then learnt

# %%
with pm.Model() as match : 
    data = np.linspace(0 , 10 , 11)
    approx = np.linspace(0,8 , 11)
    diff = np.linalg.norm(data - approx)
    prior = pm.Normal('prior', mu = 0 , sd =5)
    #mu = pm.Normal('mu' , mu = 3 , sd = 1)
    inj_param = 12
    inf_param = pm.Normal('inf' , mu = 8 , sd = 100 )
    likelihood = pm.Normal('obs' , mu = np.linalg.norm(inj_param - inf_param)
                           , sd =1 , observed = np.random.normal( 0 , 1, 1000))
    #trace = pm.sample(2000 , tune = 500)
    approx =pm.fit(n = 6000)
# Out:
# Average Loss = 4,094.7: 100%|██████████| 6000/6000 [00:09<00:00, 615.52it/s]
# Finished [100%]: Average Loss = 4,089.8

# %%
plt.figure()
trace = approx.sample(10000)
sns.distplot(trace['inf']);

# %%
fig = plt.figure(figsize=(16, 9))
hist_ax = fig.add_subplot(212)
hist_ax.plot(approx.hist)
hist_ax.set_title('Negative ELBO track')
hist_ax.set_ylabel('ELBO')
hist_ax.set_xlabel('iterarions')
# Out:
# Text(0.5,0,'iterarions')

# %% [markdown]
# ### Below we carry out a similar test but here we try to learn the co-efficients of a cubic function

# %%
with pm.Model() as match : 
    data = np.linspace(1 , 10 , 10000)
    data1 = np.linspace(1 , 10 , 10000)**2
    data2 = np.linspace(1 , 10 , 10000)**3
    inj_line = 10 * data + 4*data1 + 8 * data2 + 50
    inf_a1 = pm.Normal('inf_a1' , mu = 2 , sd = 100)
    inf_a2 = pm.Normal('inf_a2' , mu = 2 , sd = 100)
    inf_a3 = pm.Normal('inf_a3' , mu = 2 , sd = 100)
    inf_bias = pm.Normal('inf_bias' , mu = 1 , sd = 100)
    inf_line = inf_a1 * data + inf_a2 * data1 + inf_a3* data2 + inf_bias
    likelihood = pm.Normal('obs' , mu = np.linalg.norm(inj_line - inf_line)
                           , sd =1 , observed = np.random.normal( 0 , 0.1, 10000))
    #trace = pm.sample(2000 , tune = 500)
    #approx = pm.fit(5000 , method='svgd', inf_kwargs = dict(n_particles=500),
    #                    obj_optimizer= pm.sgd(learning_rate=0.0000001))
    approx = pm.fit(method = 'advi',  n = 400000)
# Out:
# Average Loss = 9,354.5: 100%|██████████| 400000/400000 [09:23<00:00, 709.43it/s]
# Finished [100%]: Average Loss = 9,354.6

# %%
# plt.plot(inj_line)

# %%
trace = approx.sample(1000)

# %%
fig = plt.figure(figsize=(16, 9))
hist_ax = fig.add_subplot(212)
hist_ax.plot(approx.hist)
hist_ax.set_title('Negative ELBO track')
hist_ax.set_ylabel('ELBO')
hist_ax.set_xlabel('iterations')
# hist_ax.set_ylim(0,10**5)
# Out:
# Text(0.5,0,'iterations')

# %%
# pm.traceplot(trace);

# %%
f, (ax1, ax2 , ax3 , ax4) = plt.subplots(4 ,figsize=(16, 14))
trace = approx.sample(5000)
sns.kdeplot(trace['inf_a1'], ax=ax1)
ax1.set_xlabel('a1')
sns.kdeplot(trace['inf_a2'], ax=ax2)
ax2.set_xlabel('a2')
sns.kdeplot(trace['inf_a3'], ax=ax3)
ax3.set_xlabel('a3')
sns.kdeplot(trace['inf_bias'], ax=ax4)
ax4.set_xlabel('bias')
# Out:
# Text(0.5,0,'bias')

# %%
with pm.Model() as match : 
    data = np.linspace(1 , 10 , 10000)
    data1 = np.linspace(1 , 10 , 10000)**2
    data2 = np.linspace(1 , 10 , 10000)**3
    inj_line = 10 * data + 4*data1 + 8 * data2 + 50
    inf_a1 = pm.Normal('inf_a1' , mu = 2 , sd = 100)
    inf_a2 = pm.Normal('inf_a2' , mu = 2 , sd = 100)
    inf_a3 = pm.Normal('inf_a3' , mu = 2 , sd = 100)
    inf_bias = pm.Normal('inf_bias' , mu = 1 , sd = 100)
    inf_line = inf_a1 * data + inf_a2 * data1 + inf_a3* data2 + inf_bias
    likelihood = pm.Normal('obs' , mu = np.linalg.norm(inj_line - inf_line)
                           , sd =1 , observed = np.random.normal( 0 , 0.1, 10000))
    #trace = pm.sample(2000 , tune = 500)
    approx = pm.fit(500 , method='svgd', inf_kwargs = dict(n_particles=500),
                        obj_optimizer= pm.sgd(learning_rate= 0.000000001))
    #approx = pm.fit(method = 'advi',  n = 400000)
# Out:
#  11%|█         | 54/500 [00:07<01:05,  6.81it/s]

# %%
f, (ax1, ax2 , ax3 , ax4) = plt.subplots(4 ,figsize=(16, 14))
sns.kdeplot(trace['inf_a1'], ax=ax1)
ax1.set_xlabel('a1')
sns.kdeplot(trace['inf_a2'], ax=ax2)
ax2.set_xlabel('a2')
sns.kdeplot(trace['inf_a3'], ax=ax3)
ax3.set_xlabel('a3')
sns.kdeplot(trace['inf_bias'], ax=ax4)
ax4.set_xlabel('bias')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-d74d910f8ea6> in <module>()
# ----> 1 f, (ax1, ax2 , ax3 , ax4) = plt.subplots(4 ,figsize=(16, 14))
#       2 sns.kdeplot(trace['inf_a1'], ax=ax1)
#       3 ax1.set_xlabel('a1')
#       4 sns.kdeplot(trace['inf_a2'], ax=ax2)
#       5 ax2.set_xlabel('a2')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1180     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1181                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1182                        gridspec_kw=gridspec_kw)
#    1183     return fig, axs
#    1184
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
# ...

# %%
with pm.Model() as match : 
    data = np.linspace(1 , 10 , 10000)
    data1 = np.linspace(1 , 10 , 10000)**2
    data2 = np.linspace(1 , 10 , 10000)**3
    inj_line = 10 * data + 4*data1 + 8 * data2 + 50
    inf_a1 = pm.Normal('inf_a1' , mu = 2 , sd = 100)
    inf_a2 = pm.Normal('inf_a2' , mu = 2 , sd = 100)
    inf_a3 = pm.Normal('inf_a3' , mu = 2 , sd = 100)
    inf_bias = pm.Normal('inf_bias' , mu = 1 , sd = 100)
    inf_line = inf_a1 * data + inf_a2 * data1 + inf_a3* data2 + inf_bias
    likelihood = pm.Normal('obs' , mu = np.linalg.norm(inj_line - inf_line) + 1
                           , sd =1 , observed = np.random.normal( 1 , 1, 10000))
    trace = pm.sample(10000 ,step = pm.NUTS() , tune = 500)
    #approx = pm.fit(5000 , method='svgd', inf_kwargs = dict(n_particles=500),
    #                    obj_optimizer= pm.sgd(learning_rate=0.0000001))
    #approx = pm.fit(method = 'advi',  n = 400000)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [inf_bias, inf_a3, inf_a2, inf_a1]
#   4%|▎         | 386/10500 [00:01<00:34, 291.42it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/Rhys/anaconda3/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 350, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Rhys/anaconda3/lib/python3.6/site-packages/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/Rhys/anaconda3/lib/python3.6/site-packages/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/Rhys/anaconda3/lib/python3.6/site-packages/pymc3/sampling.py", line 554, in _sample
# ...

# %%
pm.traceplot(trace);

# %%
with pm.Model() as match : 
    data = np.linspace(1 , 10 , 10000)
    data1 = np.linspace(1 , 10 , 10000)**2
    data2 = np.linspace(1 , 10 , 10000)**3
    inj_line = 10 * data + 4*data1 + 8 * data2 + 50
    inf_a1 = pm.Normal('inf_a1' , mu = 2 , sd = 100)
    inf_a2 = pm.Normal('inf_a2' , mu = 2 , sd = 100)
    inf_a3 = pm.Normal('inf_a3' , mu = 2 , sd = 100)
    inf_bias = pm.Normal('inf_bias' , mu = 1 , sd = 100)
    inf_line = inf_a1 * data + inf_a2 * data1 + inf_a3* data2 + inf_bias
    likelihood = pm.Normal('obs' , mu = np.linalg.norm(inj_line - inf_line)
                           , sd =1 , observed = np.random.normal( 0 , 0.1, 10000))
    trace = pm.sample(500000 ,step = pm.Metropolis(), tune = 500)
    #approx = pm.fit(5000 , method='svgd', inf_kwargs = dict(n_particles=500),
    #                    obj_optimizer= pm.sgd(learning_rate=0.0000001))
    #approx = pm.fit(method = 'advi',  n = 400000)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# CompoundStep
# >Metropolis: [inf_bias]
# >Metropolis: [inf_a3]
# >Metropolis: [inf_a2]
# >Metropolis: [inf_a1]
# 100%|██████████| 500500/500500 [10:33<00:00, 790.45it/s]
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(trace);

# %%
with pm.Model() as match : 
    data = np.linspace(1 , 10 , 10000)
    data1 = np.linspace(1 , 10 , 10000)**2
    data2 = np.linspace(1 , 10 , 10000)**3
    inj_line = 10 * data + 4*data1 + 8 * data2 + 50
    inf_a1 = pm.Normal('inf_a1' , mu = 2 , sd = 100)
    inf_a2 = pm.Normal('inf_a2' , mu = 2 , sd = 100)
    inf_a3 = pm.Normal('inf_a3' , mu = 2 , sd = 100)
    inf_bias = pm.Normal('inf_bias' , mu = 1 , sd = 100)
    inf_line = inf_a1 * data + inf_a2 * data1 + inf_a3* data2 + inf_bias
    likelihood = pm.Normal('obs' , mu = np.linalg.norm(inj_line - inf_line)
                           , sd =1 , observed = np.random.normal( 0 , 0.1, 10000))
    trace = pm.sample(10000 ,step = pm.HamiltonianMC(), tune = 500)
    #approx = pm.fit(5000 , method='svgd', inf_kwargs = dict(n_particles=500),
    #                    obj_optimizer= pm.sgd(learning_rate=0.0000001))
    #approx = pm.fit(method = 'advi',  n = 400000)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# HamiltonianMC: [inf_bias, inf_a3, inf_a2, inf_a1]
#   1%|          | 101/10500 [00:09<16:03, 10.80it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/Rhys/anaconda3/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 350, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Rhys/anaconda3/lib/python3.6/site-packages/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/Rhys/anaconda3/lib/python3.6/site-packages/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/Rhys/anaconda3/lib/python3.6/site-packages/pymc3/sampling.py", line 554, in _sample
# ...

# %%
pm.traceplot(trace);
